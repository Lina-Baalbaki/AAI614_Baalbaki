# %% [markdown]
# <a href="https://colab.research.google.com/github/Lina-Baalbaki/AAI614_Baalbaki/blob/main/week1_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Github Repository: https://github.com/Lina-Baalbaki/AAI614_Baalbaki.git

# %%
print("Hello!")
# Out:
# Hello!
